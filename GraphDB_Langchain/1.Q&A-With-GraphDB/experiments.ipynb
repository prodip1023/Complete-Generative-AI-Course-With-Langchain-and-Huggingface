# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os 
neo4j_uri = os.getenv('NEO4J_URI')
neo4j_username = os.getenv('NEO4J_USERNAME')
neo4j_password = os.getenv('NEO4J_PASSWORD')

# %%
# os.environ['NEO4J_URI'] = NEO4J_URI
# os.environ['NEO4J_USERNAME'] = NEO4J_USERNAME
# os.environ['NEO4J_PASSWORD'] = NEO4J_PASSWORD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.environ['NEO4J_URI'] = NEO4J_URI
#       2 os.environ['NEO4J_USERNAME'] = NEO4J_USERNAME
#       3 os.environ['NEO4J_PASSWORD'] = NEO4J_PASSWORD
#
# NameError: name 'NEO4J_URI' is not defined

# %%
from langchain_community.graphs import Neo4jGraph
graph = Neo4jGraph(url=neo4j_uri,username=neo4j_username,password=neo4j_password)
graph
# Out:
# /Users/hackthebox/Downloads/genai/genai/lib/python3.10/site-packages/langchain_community/graphs/neo4j_graph.py:6: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_community.graphs.graph_document import GraphDocument
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:114, in NetworkUtil._dns_resolver(address, family)
#     113 try:
# --> 114     info = NetworkUtil.get_address_info(
#     115         address.host, address.port, family=family,
#     116         type=socket.SOCK_STREAM
#     117     )
#     118 except OSError:
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:102, in NetworkUtil.get_address_info(host, port, family, type, proto, flags)
#     100 @staticmethod
#     101 def get_address_info(host, port, *, family=0, type=0, proto=0, flags=0):
# --> 102     return socket.getaddrinfo(host, port, family, type, proto, flags)
#
# File ~/Downloads/genai/genai/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 from langchain_community.graphs import Neo4jGraph
# ----> 2 graph = Neo4jGraph(url=neo4j_uri,username=neo4j_username,password=neo4j_password)
#       3 graph
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/langchain_community/graphs/neo4j_graph.py:370, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     368 # Verify connection
#     369 try:
# --> 370     self._driver.verify_connectivity()
#     371 except neo4j.exceptions.ServiceUnavailable:
#     372     raise ValueError(
#     373         "Could not connect to Neo4j database. "
#     374         "Please ensure that the url is correct"
#     375     )
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_sync/driver.py:974, in Driver.verify_connectivity(self, **config)
#     967     experimental_warn(
#     968         "All configuration key-word arguments to "
#     969         "verify_connectivity() are experimental. They might be "
#     970         "changed or removed in any future version without prior "
#     971         "notice."
#     972     )
#     973 session_config = self._read_session_config(config)
# --> 974 self._get_server_info(session_config)
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_sync/driver.py:1185, in Driver._get_server_info(self, session_config)
#    1183 def _get_server_info(self, session_config) -> ServerInfo:
#    1184     with self._session(session_config) as session:
# -> 1185         return session._get_server_info()
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_sync/work/session.py:173, in Session._get_server_info(self)
#     171 def _get_server_info(self):
#     172     assert not self._connection
# --> 173     self._connect(READ_ACCESS, liveness_check_timeout=0)
#     174     server_info = self._connection.server_info
#     175     self._disconnect()
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_sync/work/session.py:131, in Session._connect(self, access_mode, **acquire_kwargs)
#     129     access_mode = self._config.default_access_mode
#     130 try:
# --> 131     super()._connect(
#     132         access_mode, auth=self._config.auth, **acquire_kwargs
#     133     )
#     134 except asyncio.CancelledError:
#     135     self._handle_cancellation(message="_connect")
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_sync/work/workspace.py:161, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     153     else:
#     154         # This is the first time we open a connection to a server in a
#     155         # cluster environment for this session without explicitly
#    (...)
#     158         # we shall use this database explicitly for all subsequent
#     159         # actions within this session.
#     160         log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 161         self._pool.update_routing_table(
#     162             database=self._config.database,
#     163             imp_user=self._config.impersonated_user,
#     164             bookmarks=self._get_bookmarks(),
#     165             auth=auth,
#     166             acquisition_timeout=acquisition_timeout,
#     167             database_callback=self._set_cached_database
#     168         )
#     169 acquire_kwargs_ = {
#     170     "access_mode": access_mode,
#     171     "timeout": acquisition_timeout,
#    (...)
#     175     "liveness_check_timeout": None,
#     176 }
#     177 acquire_kwargs_.update(acquire_kwargs)
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:776, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     771 prefer_initial_routing_address = \
#     772     self.routing_tables[database].initialized_without_writers
#     774 if prefer_initial_routing_address:
#     775     # TODO: Test this state
# --> 776     if self._update_routing_table_from(
#     777         self.address, database=database,
#     778         imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     779         acquisition_timeout=acquisition_timeout,
#     780         database_callback=database_callback
#     781     ):
#     782         # Why is only the first initial routing address used?
#     783         return
#     784 if self._update_routing_table_from(
#     785     *(existing_routers - {self.address}), database=database,
#     786     imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     787     acquisition_timeout=acquisition_timeout,
#     788     database_callback=database_callback
#     789 ):
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:719, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     716     log.debug("[#0000]  _: <POOL> attempting to update routing "
#     717               "table from {}".format(", ".join(map(repr, routers))))
#     718 for router in routers:
# --> 719     for address in NetworkUtil.resolve_address(
#     720         router, resolver=self.pool_config.resolver
#     721     ):
#     722         new_routing_table = self.fetch_routing_table(
#     723             address=address, acquisition_timeout=acquisition_timeout,
#     724             database=database, imp_user=imp_user, bookmarks=bookmarks,
#     725             auth=auth
#     726         )
#     727         if new_routing_table is not None:
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:157, in NetworkUtil.resolve_address(address, family, resolver)
#     155             yield resolved_address
#     156 else:
# --> 157     for resolved_address in NetworkUtil._dns_resolver(
#     158         address, family=family
#     159     ):
#     160         log.debug("[#0000]  _: <RESOLVE> dns resolver out: %s",
#     161                   resolved_address)
#     162         yield resolved_address
#
# File ~/Downloads/genai/genai/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:119, in NetworkUtil._dns_resolver(address, family)
#     114     info = NetworkUtil.get_address_info(
#     115         address.host, address.port, family=family,
#     116         type=socket.SOCK_STREAM
#     117     )
#     118 except OSError:
# --> 119     raise ValueError("Cannot resolve address {}".format(address))
#     120 return _resolved_addresses_from_info(info, address._host_name)
#
# ValueError: Cannot resolve address 6772a703.databases.neo4j.io:7687
